# %%
# %matplotlib nbagg


import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.widgets import Cursor
import pandas as pd
import time
import copy
import pickle
from multiprocessing import Pool
from config import *
from profit_optimization_core import *
from profit_vs_EEPP_coeff import *

params['start_time'] = time.time()

all_data = pickle.load(open('./output/all_data_sdsdsd.pkl','rb'))

params = all_data[0]['params']
customers = all_data[0]['customers']

# %%
# for idx,EEPP_coeff in enumerate(params['EEPP_coeff_array']):
#    plot_data(all_data[idx],EEPP_coeff)

# %%
key = 't_j'
# key2 = 'circle_delta_1_bar_region'
temp1 = all_data[0]['data'][key]
temp = pd.DataFrame(data=temp1,index=params['xvals'],columns=params['yvals'])
ax = sns.heatmap(temp, cmap="YlGnBu")

s1x,s1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['s'])
d1x,d1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['d'])
ax.scatter(s1y,s1x, marker='*', s=100, color='red') 
ax.scatter(d1y,d1x, marker='*', s=100, color='red')
if params['scenario'] in ['sdsd','sssd','ssssd','sdsdsd']:
    s2x,s2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['s'])
    ax.scatter(s2y,s2x, marker='*', s=100, color='red')
if params['scenario'] in ['sdsdsd']:
    d2x,d2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['d'])
    ax.scatter(d2y,d2x, marker='*', s=100, color='red')
    s3x,s3y = idx_of_point(params['xvals'],params['yvals'],customers[3]['s'])
    ax.scatter(s3y,s3x, marker='*', s=100, color='red')

cursor = Cursor(ax, useblit=True, color='red', linewidth=2)
fig = ax.get_figure()
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
key = 'circle_delta_3_bar_region'
# key2 = 'circle_delta_1_bar_region'
temp1 = all_data[0]['data'][key]
temp = pd.DataFrame(data=temp1,index=params['xvals'],columns=params['yvals'])
ax = sns.heatmap(temp, cmap="YlGnBu")

s1x,s1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['s'])
d1x,d1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['d'])
ax.scatter(s1y,s1x, marker='*', s=100, color='red') 
ax.scatter(d1y,d1x, marker='*', s=100, color='red')
if params['scenario'] in ['sdsd','sssd','ssssd','sdsdsd']:
    s2x,s2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['s'])
    ax.scatter(s2y,s2x, marker='*', s=100, color='red')
if params['scenario'] in ['sdsdsd']:
    d2x,d2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['d'])
    ax.scatter(d2y,d2x, marker='*', s=100, color='red')
    s3x,s3y = idx_of_point(params['xvals'],params['yvals'],customers[3]['s'])
    ax.scatter(s3y,s3x, marker='*', s=100, color='red')

fig = ax.get_figure()
fig.show()
# Out:
# /Users/theja/Downloads/local/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
key = 'prob_pool'
# key2 = 'circle_delta_1_bar_region'
temp1 = all_data[0]['data'][key]
temp = pd.DataFrame(data=temp1,index=params['xvals'],columns=params['yvals'])
ax = sns.heatmap(temp, cmap="YlGnBu")

# s1x,s1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['s'])
# d1x,d1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['d'])
# s2x,s2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['s'])
# ax.scatter(s1y,s1x, marker='*', s=100, color='red') 
# ax.scatter(d1y,d1x, marker='*', s=100, color='red')
# if params['scenario'] in ['sdsd','sssd','ssssd']:
#     ax.scatter(s2y,s2x, marker='*', s=100, color='red')

fig = ax.get_figure()
fig.show()
# Out:
# /home/theja/miniconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
temp.to_csv('prob_pool.csv', sep=',', encoding='utf-8')

# %%
# import ipyvolume as ipv
# import numpy as np

# xx, yy = np.meshgrid(px_gridvals,pp_gridvals)
# ipv.clear()
# ipv.plot_surface(xx, yy, profit_surface)
# ipv.show()

# %%
# print(customers[1]['s'])
# a,b = idx_of_point(params['xvals'],params['yvals'],customers[1]['s'])
# print(params['xvals'][a],params['yvals'][b])

# %%
# print(customers[1]['d'])
# a,b = idx_of_point(params['xvals'],params['yvals'],customers[1]['d'])
# print(params['xvals'][a],params['yvals'][b])

# %%
# all_data[1]['data'].keys()

# %%
# import numpy as np
# customers[2]['s'] = np.array([1.5,2])
# customers[2]['sd'] = distance(customers[2]['s'],customers[2]['d'])
# temp_delta = (distance(customers[1]['s'],customers[2]['s']) + customers[2]['sd'] - customers[1]['sd'])/customers[1]['sd']
# print(temp_delta)

# %%
# print(degradation(temp_delta,params['degradation_multiplier']))
# print(degradation(.3,params['degradation_multiplier']))

# %%
atemp = {0:all_data}
dot_size = 250
X, Y = np.meshgrid(atemp[0][0]['params']['xvals'], atemp[0][0]['params']['yvals'])
customers = all_data[0]['customers']
# fig, ax = plt.subplots()
for idx in range(len(atemp[0])):
    if idx < len(atemp[0])-1:
#         ax.imshow(atemp[0][idx]['data'][key], interpolation='none', alpha = (idx+1)*1.0/len(atemp[0]))
        CS = plt.contour(Y,X,atemp[0][idx]['data'][key],[0],linestyles='dashed')
    else:
#         ax.imshow(atemp[0][idx]['data'][key], interpolation='none', alpha = (idx+1)*0.1)
        CS = plt.contour(Y,X,atemp[0][idx]['data'][key],[0])
    ax = plt.gca()
    ax.scatter(customers[1]['s'][0],customers[1]['s'][1], marker='.', s=dot_size, color='green') 
    ax.scatter(customers[1]['d'][0],customers[1]['d'][1], marker='.', s=dot_size, color='red')
    if idx < len(atemp[0])-1:
        plt.clabel(CS, inline=1, fontsize=10,fmt={0:str(EEPP_coeff_array[idx])})
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# plt.savefig('./output/fig_sdsd0.png')
# Out:
# /home/theja/miniconda3/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# /home/theja/miniconda3/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# /home/theja/miniconda3/lib/python3.6/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
idx = 0
fig, ax = plt.subplots()
ax.imshow(atemp[0][idx]['data'][key], interpolation='none', alpha = (idx+1)*1.0/len(atemp[0]))
plt.show()

# %%
idx = 1
fig, ax = plt.subplots()
ax.imshow(atemp[0][idx]['data'][key], interpolation='none', alpha = (idx+1)*1.0/len(atemp[0]))
plt.show()

# %%
idx = 2
fig, ax = plt.subplots()
ax.imshow(atemp[0][idx]['data'][key], interpolation='none', alpha = (idx+1)*1.0/len(atemp[0]))
plt.show()

# %%
all_data[0]['data'].keys()
# Out:
# dict_keys(['profitval', 'expost_penalty', 'ps', 'px', 'prob_pool', 'prob_exclusive', 'prob_nothing', 't_j', 'circle_s1d', 'profitval_and_prob_pool', 'circle_delta_1_bar', 'circle_delta_2_bar', 'circle_delta_3_bar', 'profitval_and_prob_pool_and_deltabars', 'circle_delta_1_bar_region', 'circle_delta_2_bar_region', 'circle_delta_3_bar_region', 'foc_condition', 'foc_condition_boundary', 'foc_condition_boundary_overlay_prob_pool', 'deltabars_intersection'])

# %%
key = 'px'
# key2 = 'circle_delta_1_bar_region'
temp1 = all_data[0]['data'][key]
temp = pd.DataFrame(data=temp1,index=params['xvals'],columns=params['yvals'])
ax = sns.heatmap(temp, cmap="YlGnBu")

s1x,s1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['s'])
d1x,d1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['d'])
ax.scatter(s1y,s1x, marker='*', s=100, color='red') 
ax.scatter(d1y,d1x, marker='*', s=100, color='red')
if params['scenario'] in ['sdsd','sssd','ssssd','sdsdsd']:
    s2x,s2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['s'])
    ax.scatter(s2y,s2x, marker='*', s=100, color='red')
if params['scenario'] in ['sdsdsd']:
    d2x,d2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['d'])
    ax.scatter(d2y,d2x, marker='*', s=100, color='red')
    s3x,s3y = idx_of_point(params['xvals'],params['yvals'],customers[3]['s'])
    ax.scatter(s3y,s3x, marker='*', s=100, color='red')

fig = ax.get_figure()
fig.show()

# %%
dot_size = 1000
key = 'foc_condition'
key2 = 'deltabars_intersection'

atemp = {}
atemp[0] = pickle.load(open('./output/all_data_sdsdsd.pkl','rb'))
atemp[1] = pickle.load(open('./output/all_data_sdsdsd.pkl','rb'))
# atemp[0] = pickle.load(open('./output/all_data_sdsd_large.pkl','rb'))
# atemp[1] = pickle.load(open('./output/all_data_sdsdsd_large.pkl','rb'))
X, Y = np.meshgrid(atemp[0][0]['params']['yvals'], atemp[0][0]['params']['xvals'])
midx = 0

params = atemp[midx][0]['params']
customers = atemp[midx][0]['customers']
s1x,s1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['s'])
d1x,d1y = idx_of_point(params['xvals'],params['yvals'],customers[1]['d'])
s2x,s2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['s'])
if params['scenario'] == 'sdsdsd':
    d2x,d2y = idx_of_point(params['xvals'],params['yvals'],customers[2]['d'])    
    s3x,s3y = idx_of_point(params['xvals'],params['yvals'],customers[3]['s'])

plt.figure(figsize=(6,6))
for idx in range(len(atemp[midx])):
    CS = plt.contour(Y,X,atemp[midx][idx]['data'][key],[0],linestyles='dashed',colors='black',linewidths=4.0)
    plt.clabel(CS, inline=1, fontsize=10,fmt={0:str(params['EEPP_coeff_array'][idx])})
    ax = plt.gca()
    ax.scatter(customers[1]['s'][0],customers[1]['s'][1], marker='.', s=dot_size, color='green') 
    ax.scatter(customers[1]['d'][0],customers[1]['d'][1], marker='.', s=dot_size, color='red')
    ax.scatter(customers[2]['s'][0],customers[2]['s'][1], marker='.', s=dot_size, color='green')
    ax.scatter(customers[2]['d'][0],customers[2]['d'][1], marker='.', s=dot_size, color='red')
    ax.scatter(customers[3]['s'][0],customers[3]['s'][1], marker='.', s=dot_size, color='green')

    ax.imshow(atemp[midx][idx]['data'][key2].transpose(),alpha=.2,extent=
           [params['x_min'],params['x_max'],params['y_min'],params['y_max']],origin='lower')
    cursor = Cursor(ax, useblit=True, color='red', linewidth=2)
# Out:
# <img src="data:image/png;base64,..." width="600">
